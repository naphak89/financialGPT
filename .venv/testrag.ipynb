# %% [markdown]
# RAG - test

# %%
#Document
question = "what is MADEUPYUGIOHFINANCEUNIVERSE is?"
document = "MADEUPYUGIOHFINANCEUNIVERSE is a new way of making money by trading on the blockchain yugioh cards, this is a new market with a community of traders and a team of developers and yugioh players working on the project."

# %%
import tiktoken

def num_token_from_string(string: str, encoding_name: str) -> int:
    """returns the number of tokens in a text string"""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

num_token_from_string(question, "cl100k_base")
# Out:
# 15

# %% [markdown]
# Text embedding model

# %%
import getpass
import os

os.environ["NVIDIA_API_KEY"]="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"

# %%
from langchain_nvidia_ai_endpoints import NVIDIAEmbeddings

embd = NVIDIAEmbeddings()
query_result = embd.embed_query(question)
document_result = embd.embed_query(document)
len(query_result)
# Out:
# 1024
